# %%
#!pip install flask

# %%
import flask
from flask import Flask, redirect, url_for, request
app = Flask(__name__)

fromData = ""
toData = ""

def gatherResult(a, b):
    print("got the data from: ", a, " and ", b)

@app.route('/success/<origin>?<dest>')
def success(origin, dest):
    fromData = origin
    toData = dest
    gatherResult(fromData, toData)
    return '''
        <!DOCTYPE html> <html> <head>
        <style>
        table {
          font-family: arial, sans-serif;
          border-collapse: collapse;
          width: 100%;
        }

        td, th {
          border: 1px solid #dddddd;
          text-align: left;
          padding: 8px;
        }

        tr:nth-child(even) {
          background-color: #dddddd;
        }
        .result{
          width: 50%;
          margin: 20px;
          padding: 20px;
        }
        </style>
        </head> <body>

        <form action = "http://localhost:5000/login" method = "post">
                 <p>Origin:</p>
                 <p><input type = "text" name = "origin" /></p>
                 <p>Destination:</p>
                 <p><input type = "text" name = "dest" /></p>
                 <p><input type = "submit" value = "Search" /></p>
        </form>

        <div class="result">
        <h2>Itinerary</h2>
        <table id = "resultTable">
          <tr>
            <th>Alternatives</th>
            <th>Distance(km)</th>
            <th>Duration(mins)</th>
            <th>CO2 emissions</th>
          </tr>
          <tr>
            <td>Cycling</td>
            <td>30</td>
            <td>25</td>
            <td>0</td>
          </tr>
          <tr>
            <td>Car</td>
            <td>35</td>
            <td>10</td>
            <td>0.8</td>
          </tr>
          <tr>
            <td>Public Transport</td>
            <td>40</td>
            <td>14</td>
            <td>0.007</td>
          </tr>
        </table>
        </div>

        </body>
        </html>'''

@app.route('/login',methods = ['POST', 'GET'])
def login():
    if request.method == 'POST':
        fromAdd = request.form['origin']
        destAdd = request.form['dest']
        return redirect(url_for('success',origin = fromAdd, dest = destAdd))
    else:
        user = request.args.get('origin')
        user = request.args.get('dest')
        return redirect(url_for('success',origin = fromAdd, dest = destAdd))

if __name__ == '__main__':
    app.run(debug = False)

# %tb
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [17/Nov/2019 00:38:51] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [17/Nov/2019 00:38:52] "GET /success/Helsinki%3Fvantaa HTTP/1.1" 200 -
# got the data from:  Helsinki  and  vantaa
# 127.0.0.1 - - [17/Nov/2019 00:41:44] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [17/Nov/2019 00:41:44] "GET /success/Helsinki%3Fvantaa HTTP/1.1" 200 -
# got the data from:  Helsinki  and  vantaa
# 127.0.0.1 - - [17/Nov/2019 00:53:11] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [17/Nov/2019 00:53:11] "GET /success/Helsinki%3Fvantaa HTTP/1.1" 200 -
# got the data from:  Helsinki  and  vantaa

# %%
'''
<script>
  window.onload = function () { 
  var table = document.getElementById("resultTable");
  var row = table.insertRow(1);
  var cell1 = row.insertCell(0);
  var cell2 = row.insertCell(1);
  var cell3 = row.insertCell(2);
  cell1.innerHTML = fromData;
  cell2.innerHTML = "NEW CELL2";
  cell3.innerHTML = "NEW CELL3";
    }
        
</script>
'''

'''
<tr>
            <td>Cycling</td>
            <td>30</td>
            <td>25</td>
            <td>0</td>
          </tr>
          <tr>
            <td>Car</td>
            <td>35</td>
            <td>10</td>
            <td>0.8</td>
          </tr>
          <tr>
            <td>Public Transport</td>
            <td>40</td>
            <td>14</td>
            <td>0.007</td>
          </tr>
'''

# %%
import flask
from flask import Flask, redirect, url_for, request
app = Flask(__name__)

fromData = ""
toData = ""

def gatherResult(a, b):
    print("got the data from: ", a, " and ", b)

@app.route('/success/<origin>?<dest>')
def success(origin, dest):
    fromData = origin
    toData = dest
    gatherResult(fromData, toData)
    return '''
        <!DOCTYPE html> <html> <head>
        <style>
        table {
          font-family: arial, sans-serif;
          border-collapse: collapse;
          width: 100%;
        }

        td, th {
          border: 1px solid #dddddd;
          text-align: left;
          padding: 8px;
        }

        tr:nth-child(even) {
          background-color: #dddddd;
        }
        .result{
          width: 50%;
          margin: 20px;
          padding: 20px;
        }
        </style>
        </head> <body>

        <form action = "http://localhost:5000/login" method = "post">
                 <p>Origin:</p>
                 <p><input type = "text" name = "origin" /></p>
                 <p>Destination:</p>
                 <p><input type = "text" name = "dest" /></p>
                 <p><input type = "submit" value = "Search" /></p>
        </form>

        <div class="result">
        <h2>Itinerary</h2>
        <table id = "resultTable">
          <tr>
            <th>Alternatives</th>
            <th>Distance(km)</th>
            <th>Duration(mins)</th>
            <th>CO2 emissions</th>
          </tr>
        </table>
        </div>
<tr>
            <td>Cycling</td>
            <td>30</td>
            <td>25</td>
            <td>0</td>
          </tr>
          <tr>
            <td>Car</td>
            <td>35</td>
            <td>10</td>
            <td>0.8</td>
          </tr>
          <tr>
            <td>Public Transport</td>
            <td>40</td>
            <td>14</td>
            <td>0.007</td>
          </tr>


        </body>
        </html>'''

@app.route('/login',methods = ['POST', 'GET'])
def login():
    if request.method == 'POST':
        fromAdd = request.form['origin']
        destAdd = request.form['dest']
        return redirect(url_for('success',origin = fromAdd, dest = destAdd))
    else:
        user = request.args.get('origin')
        user = request.args.get('dest')
        return redirect(url_for('success',origin = fromAdd, dest = destAdd))

if __name__ == '__main__':
    app.run(debug = False)

# %tb
